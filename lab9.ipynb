# %% [markdown]
# <a href="https://colab.research.google.com/github/sujithh1110/data-mining/blob/main/lab9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Salary_Data.csv')
plt.scatter(df['YearsExperience'], df['Salary'], color='blue')
plt.title('Salary vs Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
df = pd.read_csv('Salary_Data.csv')
X = df[['YearsExperience']].values
y = df['Salary'].values
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 38863.07185016361
# Coefficients: [   0.         -718.70841416 2099.35194631 -122.91541434]

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
y_pred = model.predict(X_poly)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
X_grid = np.linspace(min(X)[0], max(X)[0], 100).reshape(-1, 1)
X_grid_poly = poly.transform(X_grid)
y_grid_pred = model.predict(X_grid_poly)
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X_grid, y_grid_pred, color='red', linewidth=2, label='Polynomial Fit')
plt.title('Polynomial Regression Curve')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 26446769.61
# R² Score: 0.96
